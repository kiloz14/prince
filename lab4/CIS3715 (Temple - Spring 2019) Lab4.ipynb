# %% [markdown]
# # Lab 4
# ## More Data Scraping and EDA
#
# In this lab, you will improve your skills in scraping data from web pages, organizing the data in a desired format, and performing EDA.
#
# For this lab, we are reusing code from Harvard's CS109: https://github.com/cs109/2015/blob/master/Lectures/02-DataScrapingQuizzes.ipynb
#
# ## Lab3.A. Run code for scraping Indeed.com data
#
# You firs task will be to exectute the following blocks of code and try to understand what is happening after each line of the code. You will have to answer several questions to show your understanding.
#
# Let us start with importing of the relevant packages.

# %%
import requests
import bs4 #this is beautiful soup

import time
from pandas import Series
import pandas as pd
from pandas import DataFrame
import numpy as np
import re

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# As you see, you imported the package called `re`, which supports regular expression operations. You have already used the other packages.
#
# The following block will access and load the contents of an Indeed.com web page. It will probably give you a warning -- please ignore it.

# %%
# Fixed url for job postings containing data scientist
url = 'http://www.indeed.com/jobs?q=data+scientist&l='
# read the website
source = requests.get(url).text
# parse html code
bs_tree = bs4.BeautifulSoup(source)

# %%
#bs_tree

# %% [markdown]
# **Question 1**:
#  * What kind of page did you land on? Explain in a few sentences what is the content of this page.
#  * What does the "?" and "&" in the url mean?
#  * Explore the content of the web page. If you are using Firefox, open the page Inspector to understand how the underlying html code relates to the displayed content.
#  * What pieces of the html code are responsible for showing the job title, company name, and job location?
#
# The following block of code will figure out how many job ads are there for jobs that contain "data scientist' in the job title.

# %%
print("1. The page that I land on was a job posting page for companies that are looking to hire data scientists")
print("2. The question mark represents a query that passes in a value to a parameter ( key-value ), which in this case passes data scientist into q")
print("2b. The ampersand represents another (key-value) pair for the query")
print("3. The body is responsible for displaying location, job title and company name.")
# Out:
# 1. The page that I land on was a job posting page for companies that are looking to hire data scientists
# 2. The question mark represents a query that passes in a value to a parameter ( key-value ), which in this case passes data scientist into q
# 2b. The ampersand represents another (key-value) pair for the query
# 3. The body is responsible for displaying location, job title and company name.

# %%
# see how many job postings we found
job_count_string = bs_tree.find(id = 'searchCount').contents[0]
job_count_string = job_count_string.split()[-2]
# find_all and find() is different, find() returns the first occurence

print("Search yielded %s hits." % (job_count_string))

# now that job_count so far is still a string, 
# not an integer, and the , separator prevents 
# us from just casting it to int

job_count_digits = [int(d) for d in job_count_string if d.isdigit()]
job_count = np.sum([digit*(10**exponent) for digit, exponent in 
                    zip(job_count_digits[::-1], range(len(job_count_digits)))])

print(job_count)
# Out:
# Search yielded 33,542 hits.
# 33542

# %% [markdown]
# **Question 2**:
# * What does the "find(id = 'searchCount')" in the first line mean?
# * What does the second line do?
#
# **Question 3**:
# * Write a piece of code that finds the Salary Estimate object on the page
#
# The following piece of code allows you to find the links to all the job ads on the page.

# %%
#Question 2
print("Question 2a: The find(id=\"SearchCount\") means that from the given BSoup tree, it will return the first element that matches the id of searchCount.")
print()
print("Question 2b: The second line basically returns the 2nd element from the last index of the list, which in this case is 33,691")

#Question 3
salary = bs_tree.find(class_="rbHeader").contents[1]
print()
print("The salary estimate object is", salary) # this prints out the Salary Estimate object on the page
salary = salary.contents
salary = "".join(salary)
salary = salary.strip('\n\t')
print(salary) # this prints out just the string Salary Estimate from the page
# Out:
# Question 2a: The find(id="SearchCount") means that from the given BSoup tree, it will return the first element that matches the id of searchCount.
#
# Question 2b: The second line basically returns the 2nd element from the last index of the list, which in this case is 33,691
#
# The salary estimate object is <span aria-level="3" class="ws_bold" role="heading">
# 				Salary Estimate</span>
# Salary Estimate

# %%
# The website is only listing 10 results per page, 
# so we need to scrape them page after page
num_pages = int(np.ceil(job_count/10.0))
import math # you could use this instead of using the numpy library LOL KEKEKEKEKEKE
print(math.ceil(job_count/10.0)) # HEHEHEHEHHEHEHEHHE BOISSSSSSSSSSS

base_url = 'http://www.indeed.com'
job_links = []
for i in range(1): #do range(num_pages) if you want them all
    url = 'http://www.indeed.com/jobs?q=data+scientist&start=' + str(i*10)
    html_page = requests.get(url).text
    bs_tree = bs4.BeautifulSoup(html_page)
    job_postings = bs_tree.findAll('div', attrs={'class':'jobsearch-SerpJobCard'})
    job_ids = [jp.get('data-jk') for jp in job_postings]
    # go after each link   
    for id in job_ids:
        job_links.append(base_url + '/viewjob?jk=' + id)

    time.sleep(1)

print("We found a lot of jobs: ", len(job_links))
# Out:
# 3355
# We found a lot of jobs:  16

# %%
job_links
# Out:
# ['http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=c29ec10470153175',
#  'http://www.indeed.com/viewjob?jk=1486f8bbb9d68d93',
#  'http://www.indeed.com/viewjob?jk=851d784993c4eb81',
#  'http://www.indeed.com/viewjob?jk=738fe6188daacd19',
#  'http://www.indeed.com/viewjob?jk=b6c6149172fdf5c6',
#  'http://www.indeed.com/viewjob?jk=b485521dd0cffb12',
#  'http://www.indeed.com/viewjob?jk=08106ff509c9c18b',
#  'http://www.indeed.com/viewjob?jk=3732427d3a63339e',
#  'http://www.indeed.com/viewjob?jk=71ee734828db70f6',
#  'http://www.indeed.com/viewjob?jk=644219870743de0e',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1']

# %% [markdown]
# **Question 4**:
# * explain why is `url` (first line in the for loop) defined as it is. What page are you landing at when `i = 3`?
#
# * What does command `''bs_tree.findAll('div', attrs={'class':'jobsearch-SerpJobCard'})` do?
# * Explain the properties and content of `job_links`
#
# **Question 5**:
# * Reuse the code above to find links to the first 200 listed data science jobs
#
# The following piece of code accesses and grabs the content of all ads in the `job_links` and extracts all the human-readable text tokens. Then, it counts on how many pages are words `mapreduce`, `spark`, and `visualization` used. It might take a few seconds to execute.

# %%
# Question 4
print("Question 4a: when i is equal to 3, you are landing on the third page where the nth job posting is listed. url is defined as it is because you need to iterate through multiple pages where you only get to see 10 job postings per page. In this example, i = 1 because the for loop only executes once.")
print()
print("Question 4b: The command finds all elements in the page where the conditions are met, which in this case finds all divs who's div attributes contains class=jobsearch-SerpJobCard")
print()
print("Question 4c: The job_links is a python List containing links to the job postings of the first page, which in this case 10 different job postings. The job IDs are clearly visible in the URL. ")
print()

# Question 5
job_links = []
for i in range(14): #do range(num_pages) if you want them all
    url = 'http://www.indeed.com/jobs?q=data+scientist&start=' + str(i*10)
    html_page = requests.get(url).text
    bs_tree = bs4.BeautifulSoup(html_page)
    job_postings = bs_tree.findAll('div', attrs={'class':'jobsearch-SerpJobCard'})
    
    job_ids = [jp.get('data-jk') for jp in job_postings]
    
    # print results per page
    # print(len(job_ids))
    jobsss = 0
    # go after each link   
    for id in job_ids:
        if len(job_links) < 200:
            job_links.append(base_url + '/viewjob?jk=' + id)
            jobsss = id
        else:
            continue


    #I DON'T UNDERSTAND WHY YOU NEED A TIMER() HERE? WHAT IS IT WAITING FOR? AN AJAX CALL TO BE EXECUTED? JS FUNCTION?
    #timer.sleep(1)
    
# each page has ~15 job postings
# to get to the 200th job posting, we need to go to ceil(200/15) = ~13-14th page
# what i've noticed is that the job postings order KEEPS changing, so you might not see the same job posting result if you 
# were to type it out in the URL address bar....
job_links
# Out:
# Question 4a: when i is equal to 3, you are landing on the third page where the nth job posting is listed. url is defined as it is because you need to iterate through multiple pages where you only get to see 10 job postings per page. In this example, i = 1 because the for loop only executes once.
#
# Question 4b: The command finds all elements in the page where the conditions are met, which in this case finds all divs who's div attributes contains class=jobsearch-SerpJobCard
#
# Question 4c: The job_links is a python List containing links to the job postings of the first page, which in this case 10 different job postings. The job IDs are clearly visible in the URL.
# ['http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=c29ec10470153175',
#  'http://www.indeed.com/viewjob?jk=d38087c54d87e201',
#  'http://www.indeed.com/viewjob?jk=08106ff509c9c18b',
#  'http://www.indeed.com/viewjob?jk=b485521dd0cffb12',
#  'http://www.indeed.com/viewjob?jk=851d784993c4eb81',
#  'http://www.indeed.com/viewjob?jk=b6c6149172fdf5c6',
#  'http://www.indeed.com/viewjob?jk=738fe6188daacd19',
#  'http://www.indeed.com/viewjob?jk=830ec0678568e1ee',
#  'http://www.indeed.com/viewjob?jk=644219870743de0e',
#  'http://www.indeed.com/viewjob?jk=2acb93c6b7680f30',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=00861db3f439e643',
#  'http://www.indeed.com/viewjob?jk=8ba464250b670a7d',
#  'http://www.indeed.com/viewjob?jk=1651761a3aa8527f',
#  'http://www.indeed.com/viewjob?jk=dc75edcebf96195d',
#  'http://www.indeed.com/viewjob?jk=1486f8bbb9d68d93',
#  'http://www.indeed.com/viewjob?jk=68e31f213df42fef',
#  'http://www.indeed.com/viewjob?jk=e8f2ab289cd31d0d',
#  'http://www.indeed.com/viewjob?jk=5c0e0a406a21af2c',
#  'http://www.indeed.com/viewjob?jk=9102fb0a0b3e874d',
#  'http://www.indeed.com/viewjob?jk=c516042eac0250e1',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=ba06f541af65cfbd',
#  'http://www.indeed.com/viewjob?jk=b25880be89992d7c',
#  'http://www.indeed.com/viewjob?jk=8180ba9486fdaeb0',
#  'http://www.indeed.com/viewjob?jk=d475aa4e15f9c011',
#  'http://www.indeed.com/viewjob?jk=73162870c7c6d5a5',
#  'http://www.indeed.com/viewjob?jk=6e8cb31d77398803',
#  'http://www.indeed.com/viewjob?jk=3779fd715f0ebec2',
#  'http://www.indeed.com/viewjob?jk=2e0670a682f43a4a',
#  'http://www.indeed.com/viewjob?jk=3296f34f213da3d9',
#  'http://www.indeed.com/viewjob?jk=6f410fd6819fa6e3',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=93cbed4c70d3fee5',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=c46fdc64b5613595',
#  'http://www.indeed.com/viewjob?jk=3779fd715f0ebec2',
#  'http://www.indeed.com/viewjob?jk=6f410fd6819fa6e3',
#  'http://www.indeed.com/viewjob?jk=fddab4c1e13d3bcf',
#  'http://www.indeed.com/viewjob?jk=a1550c259c2afd21',
#  'http://www.indeed.com/viewjob?jk=7a598d72e1f593bd',
#  'http://www.indeed.com/viewjob?jk=82e4e876308bcbba',
#  'http://www.indeed.com/viewjob?jk=b25880be89992d7c',
#  'http://www.indeed.com/viewjob?jk=e961d02dec19c471',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=a5043d3f412ee986',
#  'http://www.indeed.com/viewjob?jk=2e94ba448737a35c',
#  'http://www.indeed.com/viewjob?jk=1651761a3aa8527f',
#  'http://www.indeed.com/viewjob?jk=5ed9d3f99b593962',
#  'http://www.indeed.com/viewjob?jk=61e0af58e22bab61',
#  'http://www.indeed.com/viewjob?jk=7c4f98c4badb7903',
#  'http://www.indeed.com/viewjob?jk=1088bfa6c091c72b',
#  'http://www.indeed.com/viewjob?jk=646a1d7da3539dc3',
#  'http://www.indeed.com/viewjob?jk=7a140ea5ae5529d7',
#  'http://www.indeed.com/viewjob?jk=986e534c8e1f1e02',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=c841d6a6fc60317a',
#  'http://www.indeed.com/viewjob?jk=99dc3a679faedf73',
#  'http://www.indeed.com/viewjob?jk=0141013576c93eb8',
#  'http://www.indeed.com/viewjob?jk=bbd2427fcbe7af99',
#  'http://www.indeed.com/viewjob?jk=56729aead3366f21',
#  'http://www.indeed.com/viewjob?jk=87414faf8b0a8a76',
#  'http://www.indeed.com/viewjob?jk=081156e39286dc80',
#  'http://www.indeed.com/viewjob?jk=98567bdd4c9797f1',
#  'http://www.indeed.com/viewjob?jk=7cc8b50407bf7ec0',
#  'http://www.indeed.com/viewjob?jk=57dcde19528d39bd',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=a85527c3f20539c4',
#  'http://www.indeed.com/viewjob?jk=257fcb5e1991c04e',
#  'http://www.indeed.com/viewjob?jk=c1d9c96c84e6f0ff',
#  'http://www.indeed.com/viewjob?jk=d72803a06f95951b',
#  'http://www.indeed.com/viewjob?jk=7854510962373f81',
#  'http://www.indeed.com/viewjob?jk=354363a647473c3b',
#  'http://www.indeed.com/viewjob?jk=90c6af4974cb9e35',
#  'http://www.indeed.com/viewjob?jk=ff1839ba0458a785',
#  'http://www.indeed.com/viewjob?jk=4a4901a84d075cde',
#  'http://www.indeed.com/viewjob?jk=badf193bfe2c2400',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=646a1d7da3539dc3',
#  'http://www.indeed.com/viewjob?jk=e15377253c773d1a',
#  'http://www.indeed.com/viewjob?jk=79618d9c364b37a5',
#  'http://www.indeed.com/viewjob?jk=644219870743de0e',
#  'http://www.indeed.com/viewjob?jk=b9b3c47f6c685265',
#  'http://www.indeed.com/viewjob?jk=10ebccbb5ecb73e9',
#  'http://www.indeed.com/viewjob?jk=fddab4c1e13d3bcf',
#  'http://www.indeed.com/viewjob?jk=27ac5b573efd1717',
#  'http://www.indeed.com/viewjob?jk=83a931c6a9a3b3f7',
#  'http://www.indeed.com/viewjob?jk=e3b6ebc2f1d0b263',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=0d8e273557d8479d',
#  'http://www.indeed.com/viewjob?jk=65342b48d39c44f3',
#  'http://www.indeed.com/viewjob?jk=c0e1c2e5107d5d07',
#  'http://www.indeed.com/viewjob?jk=02ca53a23f6d1f68',
#  'http://www.indeed.com/viewjob?jk=930515aa69cdd978',
#  'http://www.indeed.com/viewjob?jk=633a79db6ad49573',
#  'http://www.indeed.com/viewjob?jk=029f39e61beea8a6',
#  'http://www.indeed.com/viewjob?jk=5aea8431280bbcba',
#  'http://www.indeed.com/viewjob?jk=d4a369d1e1ad7499',
#  'http://www.indeed.com/viewjob?jk=830946c3483e5c9e',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=dffbf83b18a43159',
#  'http://www.indeed.com/viewjob?jk=007dd0cd041aa444',
#  'http://www.indeed.com/viewjob?jk=a85527c3f20539c4',
#  'http://www.indeed.com/viewjob?jk=2b76ea53c5c637eb',
#  'http://www.indeed.com/viewjob?jk=a8cb39b8c06787ae',
#  'http://www.indeed.com/viewjob?jk=04d9f8ef507af068',
#  'http://www.indeed.com/viewjob?jk=b5067f8bdd59b608',
#  'http://www.indeed.com/viewjob?jk=00aeb80e0efff7a2',
#  'http://www.indeed.com/viewjob?jk=cdf4488bd98e6a46',
#  'http://www.indeed.com/viewjob?jk=b53e401c2a6c0cf3',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=f28af5f9cbcae314',
#  'http://www.indeed.com/viewjob?jk=be33ce799b520f9d',
#  'http://www.indeed.com/viewjob?jk=6f96ec5de84316ea',
#  'http://www.indeed.com/viewjob?jk=4bd9bd076d8776fd',
#  'http://www.indeed.com/viewjob?jk=f416176faa34ddfa',
#  'http://www.indeed.com/viewjob?jk=1738548c49d42acd',
#  'http://www.indeed.com/viewjob?jk=9099c50f072017d3',
#  'http://www.indeed.com/viewjob?jk=cdf4488bd98e6a46',
#  'http://www.indeed.com/viewjob?jk=0d168336bcd50293',
#  'http://www.indeed.com/viewjob?jk=5b52084872cd51f3',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=43f1727417779980',
#  'http://www.indeed.com/viewjob?jk=94754949a0468a52',
#  'http://www.indeed.com/viewjob?jk=27eda4490fa21b14',
#  'http://www.indeed.com/viewjob?jk=6e08bd7a7743e434',
#  'http://www.indeed.com/viewjob?jk=d72803a06f95951b',
#  'http://www.indeed.com/viewjob?jk=cc581223b4962af8',
#  'http://www.indeed.com/viewjob?jk=c1e736d26bca1ce7',
#  'http://www.indeed.com/viewjob?jk=a3a5fe70449552b6',
#  'http://www.indeed.com/viewjob?jk=cc53cfb11a18cab2',
#  'http://www.indeed.com/viewjob?jk=a85527c3f20539c4',
#  'http://www.indeed.com/viewjob?jk=ac5fa8c04d5ae294',
#  'http://www.indeed.com/viewjob?jk=c1d2548297bdbb34',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=d094066d7847bcd4',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=147327f827ef98a1',
#  'http://www.indeed.com/viewjob?jk=bd900e0a52047630',
#  'http://www.indeed.com/viewjob?jk=347ee881443f895c',
#  'http://www.indeed.com/viewjob?jk=1adae89d9c4cd287',
#  'http://www.indeed.com/viewjob?jk=81a029c8c293c8f0',
#  'http://www.indeed.com/viewjob?jk=29a2dd910ca5aa4e',
#  'http://www.indeed.com/viewjob?jk=c2caed5da70fddc1',
#  'http://www.indeed.com/viewjob?jk=f3089082cfd13b1b']

# %%
skill_set = {'mapreduce':0, 'spark':0, 'visualization':0}
counter = 0
print(len(job_links))
for link in job_links:
    counter +=1  
    
    try:
        html_page = requests.get(link).text
    except urllib2.HTTPError:
        print("HTTPError:")
        continue
    except urllib2.URLError:
        print("URLError:")
        continue
    except socket.error as error:
        print("Connection closed")
        continue

    html_text = re.sub("[^a-z.+3]"," ", html_page.lower()) # replace all but the listed characters
    for key in skill_set.keys():
        if key in html_text:  
            skill_set[key] +=1
            
    if counter % 5 == 0:
        print(len(job_links) - counter)
        print(skill_set)
            
print(skill_set)
# Out:
# 200
# 195
# {'mapreduce': 0, 'spark': 1, 'visualization': 4}
# 190
# {'mapreduce': 1, 'spark': 2, 'visualization': 6}
# 185
# {'mapreduce': 1, 'spark': 2, 'visualization': 6}
# 180
# {'mapreduce': 1, 'spark': 4, 'visualization': 10}
# 175
# {'mapreduce': 1, 'spark': 4, 'visualization': 10}
# 170
# {'mapreduce': 1, 'spark': 7, 'visualization': 12}
# 165
# {'mapreduce': 1, 'spark': 9, 'visualization': 15}
# 160
# {'mapreduce': 1, 'spark': 11, 'visualization': 17}
# 155
# {'mapreduce': 2, 'spark': 13, 'visualization': 17}
# 150
# {'mapreduce': 2, 'spark': 14, 'visualization': 21}
# 145
# {'mapreduce': 2, 'spark': 15, 'visualization': 22}
# 140
# {'mapreduce': 2, 'spark': 17, 'visualization': 25}
# 135
# {'mapreduce': 2, 'spark': 18, 'visualization': 29}
# 130
# {'mapreduce': 2, 'spark': 20, 'visualization': 32}
# 125
# {'mapreduce': 2, 'spark': 20, 'visualization': 33}
# 120
# {'mapreduce': 2, 'spark': 21, 'visualization': 36}
# 115
# {'mapreduce': 2, 'spark': 23, 'visualization': 38}
# 110
# {'mapreduce': 2, 'spark': 23, 'visualization': 40}
# 105
# {'mapreduce': 2, 'spark': 24, 'visualization': 41}
# 100
# {'mapreduce': 2, 'spark': 26, 'visualization': 45}
# 95
# {'mapreduce': 2, 'spark': 27, 'visualization': 46}
# 90
# {'mapreduce': 2, 'spark': 28, 'visualization': 47}
# 85
# {'mapreduce': 2, 'spark': 29, 'visualization': 51}
# 80
# {'mapreduce': 2, 'spark': 30, 'visualization': 51}
# 75
# {'mapreduce': 2, 'spark': 32, 'visualization': 53}
# 70
# {'mapreduce': 2, 'spark': 34, 'visualization': 57}
# 65
# {'mapreduce': 3, 'spark': 35, 'visualization': 58}
# 60
# {'mapreduce': 3, 'spark': 36, 'visualization': 60}
# 55
# {'mapreduce': 3, 'spark': 38, 'visualization': 63}
# 50
# {'mapreduce': 3, 'spark': 39, 'visualization': 65}
# 45
# {'mapreduce': 3, 'spark': 40, 'visualization': 68}
# 40
# {'mapreduce': 3, 'spark': 41, 'visualization': 71}
# 35
# {'mapreduce': 3, 'spark': 43, 'visualization': 73}
# 30
# {'mapreduce': 3, 'spark': 43, 'visualization': 74}
# 25
# {'mapreduce': 3, 'spark': 43, 'visualization': 78}
# 20
# {'mapreduce': 3, 'spark': 44, 'visualization': 80}
# 15
# {'mapreduce': 3, 'spark': 47, 'visualization': 83}
# 10
# {'mapreduce': 3, 'spark': 48, 'visualization': 86}
# 5
# {'mapreduce': 3, 'spark': 51, 'visualization': 91}
# 0
# {'mapreduce': 3, 'spark': 53, 'visualization': 93}
# {'mapreduce': 3, 'spark': 53, 'visualization': 93}

# %% [markdown]
# **Question 6**
# * What does the `re.sub()` do in the above code? To answer this, you will have to go to the documentation of the regular expression package (find it on web).
# * What is the meaning of `[^a-z.+3]`?
# * What is the content of `skill_set`?
#
# The following piece of code plots the counts of different skills in the processed ads.

# %%
print("Question 6a: The re.sub() method replaces the given regular expression, which in this case anything but alphabets, with the given string, which in this case is just an empty space")
print()
print("Question 6b: The meaning of [^a-z.+3] is find every character that is not an alphabet.")
print()
print("Question 6c: The content of skill_set is a dictionary that has words as keys and the number of those words as the values of the dictionary.")
# Out:
# Question 6a: The re.sub() method replaces the given regular expression, which in this case anything but alphabets, with the given string, which in this case is just an empty space
#
# Question 6b: The meaning of [^a-z.+3] is find every character that is not an alphabet.
#
# Question 6c: The content of skill_set is a dictionary that has words as keys and the number of those words as the values of the dictionary.

# %%
pseries = pd.Series(skill_set)
pseries.sort_values(ascending=False)

pseries.plot(kind = 'bar')
## set the title to Score Comparison
plt.title('Data Science Skills')
## set the x label
plt.xlabel('Skills')
## set the y label
plt.ylabel('Count')
## show the plot
plt.show()

# %% [markdown]
# **Question 7**:
# - rerun the code to find the counts of the 3 data science skills on the first 200 job ads

# %%
# Question 7 
pseries = pd.Series(skill_set)
pseries.sort_values(ascending=False)

pseries.plot(kind = 'bar')
## set the title to Score Comparison
plt.title('Data Science Skills')
## set the x label
plt.xlabel('Skills')
## set the y label
plt.ylabel('Count')
## show the plot
plt.show()

# %% [markdown]
# ## Lab 3.B: Data analysis of job skills
# In the first part of the lab, you created `skill_set` dictionary that counts occurences of 3 important data science skills. In this part of the lab we are asking you to create pandas `DataFrame` object as a table whose rows correspond to individual ads and columns correspond to important information about the ads and skills mentioned on those pages. Let us call the table `job_ads`. Process the first 1,000 data science ads, so your table should have 1,000 rows. For each ad, you will have to create the following columns:
# - job title
# - company name
# - job location
# - skill 1
# - skill 2
# - ...
# - skill 20
#
# Job title, company name, and job locations will be readable from the Indeed.com page. We are asking you to list 20 skills, instead of only 3 in the code above ('mapreduce', 'spark', 'visualization'). You will need to find another 17 words that are commonly used in data science job ads. To do it, please explore the content of at least 10 ads.
#
# Once you creat your `job_ads` table, please preform EDA of the table, in a similar way you did in Lab 2: provide code and a 2-page document that summarizes interesitng insights about the first 1,000 data science jobs.
#
# **Deliverables**:
# - the modified Lab 4 .ipynb file that contains all the answers to the questions
# - a 2-page documents presenting the results of your EDA of the `job_ads` data

# %%
# 17 different skills
skill_set['hadoop'] = []
skill_set['analytics'] = []
skill_set['mining'] = []
skill_set['presentation'] = []
skill_set['dashboards'] = []
skill_set['statistics'] = []
skill_set['collaborate'] = []
skill_set['testing'] = []
skill_set['research'] = []
skill_set['algorithms'] = []
skill_set['python'] = []
skill_set['communication'] = []
skill_set['excel'] = []
skill_set['Java'] = []
skill_set['machine learning'] = []
skill_set['regression'] = []
skill_set['matlab'] = []
skill_set['spark'] = []
skill_set['visualization'] = []
skill_set['mapreduce'] = []
d = {'job title': [], 'company name': [], 'job location': []}

# concatenates the two dictionaries
d = {**d, **skill_set}

#df = pd.DataFrame(data=d)


# code to execute the web scraping for job title, company name, location and the 20 job skills.
job_links = []
jobids = []
for i in range(67): #do range(num_pages) if you want them all
    url = 'http://www.indeed.com/jobs?q=data+scientist&start=' + str(i*10)
    html_page = requests.get(url).text
    bs_tree = bs4.BeautifulSoup(html_page)
    job_postings = bs_tree.findAll('div', attrs={'class':'jobsearch-SerpJobCard'})
    
    job_ids = [jp.get('data-jk') for jp in job_postings]
    
    # print results per page
    # print(len(job_ids))
    jobsss = 0
    # go after each link   
    for id in job_ids:
        if len(job_links) < 1000:
            job_links.append(base_url + '/viewjob?jk=' + id)
            jobsss = id
            jobids.append(id)
        else:
            continue
         
count = 0
for id in jobids: #do range(num_pages) if you want them all
    url = 'https://www.indeed.com/viewjob?jk=' + id
    print("Execution stage......", count,"/1000")
    count += 1
    html_page = requests.get(url).text
    bs_tree = bs4.BeautifulSoup(html_page)

    job_locations = bs_tree.findAll('div', attrs={'class':'jobsearch-InlineCompanyRating'})
    # determines the location of the job listing
    location = job_locations[0].findAll('div')[-1].get_text()
    
    # determines the job title from the job listing
    job_titles = bs_tree.findAll('div', attrs={'class': 'jobsearch-DesktopStickyContainer'})
    titles = job_titles[0].findAll('h3')[0].get_text()
    
    # determines the company name from the job listing
    company_names = bs_tree.findAll('div', attrs={'class':'jobsearch-InlineCompanyRating'})
    name = company_names[0].findAll('div')[0].get_text()
    
    # append the company name, location and title to the dictionary
    d['job title'].append(titles)
    d['job location'].append(location)
    d['company name'].append(name)

    # retrieve HTML page
    try:
        html_page = requests.get(url).text
    except urllib2.HTTPError:
        print("HTTPError:")
        continue
    except urllib2.URLError:
        print("URLError:")
        continue
    except socket.error as error:
        print("Connection closed")
        continue
        
    temp = {}
    temp['spark'] = 0
    temp['mapreduce'] = 0
    temp['visualization'] = 0
    temp['hadoop'] = 0
    temp['analytics'] = 0
    temp['mining'] = 0
    temp['presentation'] = 0
    temp['dashboards'] = 0
    temp['statistics'] = 0
    temp['collaborate'] = 0
    temp['testing'] = 0
    temp['research'] = 0
    temp['algorithms'] = 0
    temp['python'] = 0
    temp['communication'] = 0
    temp['excel'] = 0
    temp['Java'] = 0
    temp['machine learning'] = 0
    temp['regression'] = 0
    temp['matlab'] = 0           
        
    html_text = re.sub("[^a-z.+3]"," ", html_page.lower()) # replace all but the listed characters
    for key,value in temp.items():
        if key in html_text:  
            temp[key] += 1

    for key, value in temp.items():
        d[key].append(value)
    

    
#    skill_set[key].append()

    # print results per page
    # print(len(job_ids))
d = pd.DataFrame(data=d)
job_ads = d
# Out:
# Execution stage...... 0 /1000
# Execution stage...... 1 /1000
# Execution stage...... 2 /1000
# Execution stage...... 3 /1000
# Execution stage...... 4 /1000
# Execution stage...... 5 /1000
# Execution stage...... 6 /1000
# Execution stage...... 7 /1000
# Execution stage...... 8 /1000
# Execution stage...... 9 /1000
# Execution stage...... 10 /1000
# Execution stage...... 11 /1000
# Execution stage...... 12 /1000
# Execution stage...... 13 /1000
# Execution stage...... 14 /1000
# Execution stage...... 15 /1000
# Execution stage...... 16 /1000
# Execution stage...... 17 /1000
# Execution stage...... 18 /1000
# Execution stage...... 19 /1000
# Execution stage...... 20 /1000
# Execution stage...... 21 /1000
# Execution stage...... 22 /1000
# Execution stage...... 23 /1000
# Execution stage...... 24 /1000
# Execution stage...... 25 /1000
# Execution stage...... 26 /1000
# Execution stage...... 27 /1000
# Execution stage...... 28 /1000
# Execution stage...... 29 /1000
# Execution stage...... 30 /1000
# Execution stage...... 31 /1000
# Execution stage...... 32 /1000
# Execution stage...... 33 /1000
# Execution stage...... 34 /1000
# Execution stage...... 35 /1000
# Execution stage...... 36 /1000
# Execution stage...... 37 /1000
# Execution stage...... 38 /1000
# Execution stage...... 39 /1000
# Execution stage...... 40 /1000
# Execution stage...... 41 /1000
# Execution stage...... 42 /1000
# Execution stage...... 43 /1000
# Execution stage...... 44 /1000
# Execution stage...... 45 /1000
# Execution stage...... 46 /1000
# Execution stage...... 47 /1000
# Execution stage...... 48 /1000
# Execution stage...... 49 /1000
# Execution stage...... 50 /1000
# Execution stage...... 51 /1000
# Execution stage...... 52 /1000
# Execution stage...... 53 /1000
# Execution stage...... 54 /1000
# Execution stage...... 55 /1000
# Execution stage...... 56 /1000
# Execution stage...... 57 /1000
# Execution stage...... 58 /1000
# Execution stage...... 59 /1000
# Execution stage...... 60 /1000
# Execution stage...... 61 /1000
# Execution stage...... 62 /1000
# Execution stage...... 63 /1000
# Execution stage...... 64 /1000
# Execution stage...... 65 /1000
# Execution stage...... 66 /1000
# Execution stage...... 67 /1000
# Execution stage...... 68 /1000
# Execution stage...... 69 /1000
# Execution stage...... 70 /1000
# Execution stage...... 71 /1000
# Execution stage...... 72 /1000
# Execution stage...... 73 /1000
# Execution stage...... 74 /1000
# Execution stage...... 75 /1000
# Execution stage...... 76 /1000
# Execution stage...... 77 /1000
# Execution stage...... 78 /1000
# Execution stage...... 79 /1000
# Execution stage...... 80 /1000
# Execution stage...... 81 /1000
# Execution stage...... 82 /1000
# Execution stage...... 83 /1000
# Execution stage...... 84 /1000
# Execution stage...... 85 /1000
# Execution stage...... 86 /1000
# Execution stage...... 87 /1000
# Execution stage...... 88 /1000
# Execution stage...... 89 /1000
# Execution stage...... 90 /1000
# Execution stage...... 91 /1000
# Execution stage...... 92 /1000
# Execution stage...... 93 /1000
# Execution stage...... 94 /1000
# Execution stage...... 95 /1000
# Execution stage...... 96 /1000
# Execution stage...... 97 /1000
# Execution stage...... 98 /1000
# Execution stage...... 99 /1000
# Execution stage...... 100 /1000
# Execution stage...... 101 /1000
# Execution stage...... 102 /1000
# Execution stage...... 103 /1000
# Execution stage...... 104 /1000
# Execution stage...... 105 /1000
# Execution stage...... 106 /1000
# Execution stage...... 107 /1000
# Execution stage...... 108 /1000
# Execution stage...... 109 /1000
# Execution stage...... 110 /1000
# Execution stage...... 111 /1000
# Execution stage...... 112 /1000
# Execution stage...... 113 /1000
# Execution stage...... 114 /1000
# Execution stage...... 115 /1000
# Execution stage...... 116 /1000
# Execution stage...... 117 /1000
# Execution stage...... 118 /1000
# Execution stage...... 119 /1000
# Execution stage...... 120 /1000
# Execution stage...... 121 /1000
# Execution stage...... 122 /1000
# Execution stage...... 123 /1000
# Execution stage...... 124 /1000
# Execution stage...... 125 /1000
# Execution stage...... 126 /1000
# Execution stage...... 127 /1000
# Execution stage...... 128 /1000
# Execution stage...... 129 /1000
# Execution stage...... 130 /1000
# Execution stage...... 131 /1000
# Execution stage...... 132 /1000
# Execution stage...... 133 /1000
# Execution stage...... 134 /1000
# Execution stage...... 135 /1000
# Execution stage...... 136 /1000
# Execution stage...... 137 /1000
# Execution stage...... 138 /1000
# Execution stage...... 139 /1000
# Execution stage...... 140 /1000
# Execution stage...... 141 /1000
# Execution stage...... 142 /1000
# Execution stage...... 143 /1000
# Execution stage...... 144 /1000
# Execution stage...... 145 /1000
# Execution stage...... 146 /1000
# Execution stage...... 147 /1000
# Execution stage...... 148 /1000
# Execution stage...... 149 /1000
# Execution stage...... 150 /1000
# Execution stage...... 151 /1000
# Execution stage...... 152 /1000
# Execution stage...... 153 /1000
# Execution stage...... 154 /1000
# Execution stage...... 155 /1000
# Execution stage...... 156 /1000
# Execution stage...... 157 /1000
# Execution stage...... 158 /1000
# Execution stage...... 159 /1000
# Execution stage...... 160 /1000
# Execution stage...... 161 /1000
# Execution stage...... 162 /1000
# Execution stage...... 163 /1000
# Execution stage...... 164 /1000
# Execution stage...... 165 /1000
# Execution stage...... 166 /1000
# Execution stage...... 167 /1000
# Execution stage...... 168 /1000
# Execution stage...... 169 /1000
# Execution stage...... 170 /1000
# Execution stage...... 171 /1000
# Execution stage...... 172 /1000
# Execution stage...... 173 /1000
# Execution stage...... 174 /1000
# Execution stage...... 175 /1000
# Execution stage...... 176 /1000
# Execution stage...... 177 /1000
# Execution stage...... 178 /1000
# Execution stage...... 179 /1000
# Execution stage...... 180 /1000
# Execution stage...... 181 /1000
# Execution stage...... 182 /1000
# Execution stage...... 183 /1000
# Execution stage...... 184 /1000
# Execution stage...... 185 /1000
# Execution stage...... 186 /1000
# Execution stage...... 187 /1000
# Execution stage...... 188 /1000
# Execution stage...... 189 /1000
# Execution stage...... 190 /1000
# Execution stage...... 191 /1000
# Execution stage...... 192 /1000
# Execution stage...... 193 /1000
# Execution stage...... 194 /1000
# Execution stage...... 195 /1000
# Execution stage...... 196 /1000
# Execution stage...... 197 /1000
# Execution stage...... 198 /1000
# Execution stage...... 199 /1000
# Execution stage...... 200 /1000
# Execution stage...... 201 /1000
# Execution stage...... 202 /1000
# Execution stage...... 203 /1000
# Execution stage...... 204 /1000
# Execution stage...... 205 /1000
# Execution stage...... 206 /1000
# Execution stage...... 207 /1000
# Execution stage...... 208 /1000
# Execution stage...... 209 /1000
# Execution stage...... 210 /1000
# Execution stage...... 211 /1000
# Execution stage...... 212 /1000
# Execution stage...... 213 /1000
# Execution stage...... 214 /1000
# Execution stage...... 215 /1000
# Execution stage...... 216 /1000
# Execution stage...... 217 /1000
# Execution stage...... 218 /1000
# Execution stage...... 219 /1000
# Execution stage...... 220 /1000
# Execution stage...... 221 /1000
# Execution stage...... 222 /1000
# Execution stage...... 223 /1000
# Execution stage...... 224 /1000
# Execution stage...... 225 /1000
# Execution stage...... 226 /1000
# Execution stage...... 227 /1000
# Execution stage...... 228 /1000
# Execution stage...... 229 /1000
# Execution stage...... 230 /1000
# Execution stage...... 231 /1000
# Execution stage...... 232 /1000
# Execution stage...... 233 /1000
# Execution stage...... 234 /1000
# Execution stage...... 235 /1000
# Execution stage...... 236 /1000
# Execution stage...... 237 /1000
# Execution stage...... 238 /1000
# Execution stage...... 239 /1000
# Execution stage...... 240 /1000
# Execution stage...... 241 /1000
# Execution stage...... 242 /1000
# Execution stage...... 243 /1000
# Execution stage...... 244 /1000
# Execution stage...... 245 /1000
# Execution stage...... 246 /1000
# Execution stage...... 247 /1000
# Execution stage...... 248 /1000
# Execution stage...... 249 /1000
# Execution stage...... 250 /1000
# Execution stage...... 251 /1000
# Execution stage...... 252 /1000
# Execution stage...... 253 /1000
# Execution stage...... 254 /1000
# Execution stage...... 255 /1000
# Execution stage...... 256 /1000
# Execution stage...... 257 /1000
# Execution stage...... 258 /1000
# Execution stage...... 259 /1000
# Execution stage...... 260 /1000
# Execution stage...... 261 /1000
# Execution stage...... 262 /1000
# Execution stage...... 263 /1000
# Execution stage...... 264 /1000
# Execution stage...... 265 /1000
# Execution stage...... 266 /1000
# Execution stage...... 267 /1000
# Execution stage...... 268 /1000
# Execution stage...... 269 /1000
# Execution stage...... 270 /1000
# Execution stage...... 271 /1000
# Execution stage...... 272 /1000
# Execution stage...... 273 /1000
# Execution stage...... 274 /1000
# Execution stage...... 275 /1000
# Execution stage...... 276 /1000
# Execution stage...... 277 /1000
# Execution stage...... 278 /1000
# Execution stage...... 279 /1000
# Execution stage...... 280 /1000
# Execution stage...... 281 /1000
# Execution stage...... 282 /1000
# Execution stage...... 283 /1000
# Execution stage...... 284 /1000
# Execution stage...... 285 /1000
# Execution stage...... 286 /1000
# Execution stage...... 287 /1000
# Execution stage...... 288 /1000
# Execution stage...... 289 /1000
# Execution stage...... 290 /1000
# Execution stage...... 291 /1000
# Execution stage...... 292 /1000
# Execution stage...... 293 /1000
# Execution stage...... 294 /1000
# Execution stage...... 295 /1000
# Execution stage...... 296 /1000
# Execution stage...... 297 /1000
# Execution stage...... 298 /1000
# Execution stage...... 299 /1000
# Execution stage...... 300 /1000
# Execution stage...... 301 /1000
# Execution stage...... 302 /1000
# Execution stage...... 303 /1000
# Execution stage...... 304 /1000
# Execution stage...... 305 /1000
# Execution stage...... 306 /1000
# Execution stage...... 307 /1000
# Execution stage...... 308 /1000
# Execution stage...... 309 /1000
# Execution stage...... 310 /1000
# Execution stage...... 311 /1000
# Execution stage...... 312 /1000
# Execution stage...... 313 /1000
# Execution stage...... 314 /1000
# Execution stage...... 315 /1000
# Execution stage...... 316 /1000
# Execution stage...... 317 /1000
# Execution stage...... 318 /1000
# Execution stage...... 319 /1000
# Execution stage...... 320 /1000
# Execution stage...... 321 /1000
# Execution stage...... 322 /1000
# Execution stage...... 323 /1000
# Execution stage...... 324 /1000
# Execution stage...... 325 /1000
# Execution stage...... 326 /1000
# Execution stage...... 327 /1000
# Execution stage...... 328 /1000
# Execution stage...... 329 /1000
# Execution stage...... 330 /1000
# Execution stage...... 331 /1000
# Execution stage...... 332 /1000
# Execution stage...... 333 /1000
# Execution stage...... 334 /1000
# Execution stage...... 335 /1000
# Execution stage...... 336 /1000
# Execution stage...... 337 /1000
# Execution stage...... 338 /1000
# Execution stage...... 339 /1000
# Execution stage...... 340 /1000
# Execution stage...... 341 /1000
# Execution stage...... 342 /1000
# Execution stage...... 343 /1000
# Execution stage...... 344 /1000
# Execution stage...... 345 /1000
# Execution stage...... 346 /1000
# Execution stage...... 347 /1000
# Execution stage...... 348 /1000
# Execution stage...... 349 /1000
# Execution stage...... 350 /1000
# Execution stage...... 351 /1000
# Execution stage...... 352 /1000
# Execution stage...... 353 /1000
# Execution stage...... 354 /1000
# Execution stage...... 355 /1000
# Execution stage...... 356 /1000
# Execution stage...... 357 /1000
# Execution stage...... 358 /1000
# Execution stage...... 359 /1000
# Execution stage...... 360 /1000
# Execution stage...... 361 /1000
# Execution stage...... 362 /1000
# Execution stage...... 363 /1000
# Execution stage...... 364 /1000
# Execution stage...... 365 /1000
# Execution stage...... 366 /1000
# Execution stage...... 367 /1000
# Execution stage...... 368 /1000
# Execution stage...... 369 /1000
# Execution stage...... 370 /1000
# Execution stage...... 371 /1000
# Execution stage...... 372 /1000
# Execution stage...... 373 /1000
# Execution stage...... 374 /1000
# Execution stage...... 375 /1000
# Execution stage...... 376 /1000
# Execution stage...... 377 /1000
# Execution stage...... 378 /1000
# Execution stage...... 379 /1000
# Execution stage...... 380 /1000
# Execution stage...... 381 /1000
# Execution stage...... 382 /1000
# Execution stage...... 383 /1000
# Execution stage...... 384 /1000
# Execution stage...... 385 /1000
# Execution stage...... 386 /1000
# Execution stage...... 387 /1000
# Execution stage...... 388 /1000
# Execution stage...... 389 /1000
# Execution stage...... 390 /1000
# Execution stage...... 391 /1000
# Execution stage...... 392 /1000
# Execution stage...... 393 /1000
# Execution stage...... 394 /1000
# Execution stage...... 395 /1000
# Execution stage...... 396 /1000
# Execution stage...... 397 /1000
# Execution stage...... 398 /1000
# Execution stage...... 399 /1000
# Execution stage...... 400 /1000
# Execution stage...... 401 /1000
# Execution stage...... 402 /1000
# Execution stage...... 403 /1000
# Execution stage...... 404 /1000
# Execution stage...... 405 /1000
# Execution stage...... 406 /1000
# Execution stage...... 407 /1000
# Execution stage...... 408 /1000
# Execution stage...... 409 /1000
# Execution stage...... 410 /1000
# Execution stage...... 411 /1000
# Execution stage...... 412 /1000
# Execution stage...... 413 /1000
# Execution stage...... 414 /1000
# Execution stage...... 415 /1000
# Execution stage...... 416 /1000
# Execution stage...... 417 /1000
# Execution stage...... 418 /1000
# Execution stage...... 419 /1000
# Execution stage...... 420 /1000
# Execution stage...... 421 /1000
# Execution stage...... 422 /1000
# Execution stage...... 423 /1000
# Execution stage...... 424 /1000
# Execution stage...... 425 /1000
# Execution stage...... 426 /1000
# Execution stage...... 427 /1000
# Execution stage...... 428 /1000
# Execution stage...... 429 /1000
# Execution stage...... 430 /1000
# Execution stage...... 431 /1000
# Execution stage...... 432 /1000
# Execution stage...... 433 /1000
# Execution stage...... 434 /1000
# Execution stage...... 435 /1000
# Execution stage...... 436 /1000
# Execution stage...... 437 /1000
# Execution stage...... 438 /1000
# Execution stage...... 439 /1000
# Execution stage...... 440 /1000
# Execution stage...... 441 /1000
# Execution stage...... 442 /1000
# Execution stage...... 443 /1000
# Execution stage...... 444 /1000
# Execution stage...... 445 /1000
# Execution stage...... 446 /1000
# Execution stage...... 447 /1000
# Execution stage...... 448 /1000
# Execution stage...... 449 /1000
# Execution stage...... 450 /1000
# Execution stage...... 451 /1000
# Execution stage...... 452 /1000
# Execution stage...... 453 /1000
# Execution stage...... 454 /1000
# Execution stage...... 455 /1000
# Execution stage...... 456 /1000
# Execution stage...... 457 /1000
# Execution stage...... 458 /1000
# Execution stage...... 459 /1000
# Execution stage...... 460 /1000
# Execution stage...... 461 /1000
# Execution stage...... 462 /1000
# Execution stage...... 463 /1000
# Execution stage...... 464 /1000
# Execution stage...... 465 /1000
# Execution stage...... 466 /1000
# Execution stage...... 467 /1000
# Execution stage...... 468 /1000
# Execution stage...... 469 /1000
# Execution stage...... 470 /1000
# Execution stage...... 471 /1000
# Execution stage...... 472 /1000
# Execution stage...... 473 /1000
# Execution stage...... 474 /1000
# Execution stage...... 475 /1000
# Execution stage...... 476 /1000
# Execution stage...... 477 /1000
# Execution stage...... 478 /1000
# Execution stage...... 479 /1000
# Execution stage...... 480 /1000
# Execution stage...... 481 /1000
# Execution stage...... 482 /1000
# Execution stage...... 483 /1000
# Execution stage...... 484 /1000
# Execution stage...... 485 /1000
# Execution stage...... 486 /1000
# Execution stage...... 487 /1000
# Execution stage...... 488 /1000
# Execution stage...... 489 /1000
# Execution stage...... 490 /1000
# Execution stage...... 491 /1000
# Execution stage...... 492 /1000
# Execution stage...... 493 /1000
# Execution stage...... 494 /1000
# Execution stage...... 495 /1000
# Execution stage...... 496 /1000
# Execution stage...... 497 /1000
# Execution stage...... 498 /1000
# Execution stage...... 499 /1000
# Execution stage...... 500 /1000
# Execution stage...... 501 /1000
# Execution stage...... 502 /1000
# Execution stage...... 503 /1000
# Execution stage...... 504 /1000
# Execution stage...... 505 /1000
# Execution stage...... 506 /1000
# Execution stage...... 507 /1000
# Execution stage...... 508 /1000
# Execution stage...... 509 /1000
# Execution stage...... 510 /1000
# Execution stage...... 511 /1000
# Execution stage...... 512 /1000
# Execution stage...... 513 /1000
# Execution stage...... 514 /1000
# Execution stage...... 515 /1000
# Execution stage...... 516 /1000
# Execution stage...... 517 /1000
# Execution stage...... 518 /1000
# Execution stage...... 519 /1000
# Execution stage...... 520 /1000
# Execution stage...... 521 /1000
# Execution stage...... 522 /1000
# Execution stage...... 523 /1000
# Execution stage...... 524 /1000
# Execution stage...... 525 /1000
# Execution stage...... 526 /1000
# Execution stage...... 527 /1000
# Execution stage...... 528 /1000
# Execution stage...... 529 /1000
# Execution stage...... 530 /1000
# Execution stage...... 531 /1000
# Execution stage...... 532 /1000
# Execution stage...... 533 /1000
# Execution stage...... 534 /1000
# Execution stage...... 535 /1000
# Execution stage...... 536 /1000
# Execution stage...... 537 /1000
# Execution stage...... 538 /1000
# Execution stage...... 539 /1000
# Execution stage...... 540 /1000
# Execution stage...... 541 /1000
# Execution stage...... 542 /1000
# Execution stage...... 543 /1000
# Execution stage...... 544 /1000
# Execution stage...... 545 /1000
# Execution stage...... 546 /1000
# Execution stage...... 547 /1000
# Execution stage...... 548 /1000
# Execution stage...... 549 /1000
# Execution stage...... 550 /1000
# Execution stage...... 551 /1000
# Execution stage...... 552 /1000
# Execution stage...... 553 /1000
# Execution stage...... 554 /1000
# Execution stage...... 555 /1000
# Execution stage...... 556 /1000
# Execution stage...... 557 /1000
# Execution stage...... 558 /1000
# Execution stage...... 559 /1000
# Execution stage...... 560 /1000
# Execution stage...... 561 /1000
# Execution stage...... 562 /1000
# Execution stage...... 563 /1000
# Execution stage...... 564 /1000
# Execution stage...... 565 /1000
# Execution stage...... 566 /1000
# Execution stage...... 567 /1000
# Execution stage...... 568 /1000
# Execution stage...... 569 /1000
# Execution stage...... 570 /1000
# Execution stage...... 571 /1000
# Execution stage...... 572 /1000
# Execution stage...... 573 /1000
# Execution stage...... 574 /1000
# Execution stage...... 575 /1000
# Execution stage...... 576 /1000
# Execution stage...... 577 /1000
# Execution stage...... 578 /1000
# Execution stage...... 579 /1000
# Execution stage...... 580 /1000
# Execution stage...... 581 /1000
# Execution stage...... 582 /1000
# Execution stage...... 583 /1000
# Execution stage...... 584 /1000
# Execution stage...... 585 /1000
# Execution stage...... 586 /1000
# Execution stage...... 587 /1000
# Execution stage...... 588 /1000
# Execution stage...... 589 /1000
# Execution stage...... 590 /1000
# Execution stage...... 591 /1000
# Execution stage...... 592 /1000
# Execution stage...... 593 /1000
# Execution stage...... 594 /1000
# Execution stage...... 595 /1000
# Execution stage...... 596 /1000
# Execution stage...... 597 /1000
# Execution stage...... 598 /1000
# Execution stage...... 599 /1000
# Execution stage...... 600 /1000
# Execution stage...... 601 /1000
# Execution stage...... 602 /1000
# Execution stage...... 603 /1000
# Execution stage...... 604 /1000
# Execution stage...... 605 /1000
# Execution stage...... 606 /1000
# Execution stage...... 607 /1000
# Execution stage...... 608 /1000
# Execution stage...... 609 /1000
# Execution stage...... 610 /1000
# Execution stage...... 611 /1000
# Execution stage...... 612 /1000
# Execution stage...... 613 /1000
# Execution stage...... 614 /1000
# Execution stage...... 615 /1000
# Execution stage...... 616 /1000
# Execution stage...... 617 /1000
# Execution stage...... 618 /1000
# Execution stage...... 619 /1000
# Execution stage...... 620 /1000
# Execution stage...... 621 /1000
# Execution stage...... 622 /1000
# Execution stage...... 623 /1000
# Execution stage...... 624 /1000
# Execution stage...... 625 /1000
# Execution stage...... 626 /1000
# Execution stage...... 627 /1000
# Execution stage...... 628 /1000
# Execution stage...... 629 /1000
# Execution stage...... 630 /1000
# Execution stage...... 631 /1000
# Execution stage...... 632 /1000
# Execution stage...... 633 /1000
# Execution stage...... 634 /1000
# Execution stage...... 635 /1000
# Execution stage...... 636 /1000
# Execution stage...... 637 /1000
# Execution stage...... 638 /1000
# Execution stage...... 639 /1000
# Execution stage...... 640 /1000
# Execution stage...... 641 /1000
# Execution stage...... 642 /1000
# Execution stage...... 643 /1000
# Execution stage...... 644 /1000
# Execution stage...... 645 /1000
# Execution stage...... 646 /1000
# Execution stage...... 647 /1000
# Execution stage...... 648 /1000
# Execution stage...... 649 /1000
# Execution stage...... 650 /1000
# Execution stage...... 651 /1000
# Execution stage...... 652 /1000
# Execution stage...... 653 /1000
# Execution stage...... 654 /1000
# Execution stage...... 655 /1000
# Execution stage...... 656 /1000
# Execution stage...... 657 /1000
# Execution stage...... 658 /1000
# Execution stage...... 659 /1000
# Execution stage...... 660 /1000
# Execution stage...... 661 /1000
# Execution stage...... 662 /1000
# Execution stage...... 663 /1000
# Execution stage...... 664 /1000
# Execution stage...... 665 /1000
# Execution stage...... 666 /1000
# Execution stage...... 667 /1000
# Execution stage...... 668 /1000
# Execution stage...... 669 /1000
# Execution stage...... 670 /1000
# Execution stage...... 671 /1000
# Execution stage...... 672 /1000
# Execution stage...... 673 /1000
# Execution stage...... 674 /1000
# Execution stage...... 675 /1000
# Execution stage...... 676 /1000
# Execution stage...... 677 /1000
# Execution stage...... 678 /1000
# Execution stage...... 679 /1000
# Execution stage...... 680 /1000
# Execution stage...... 681 /1000
# Execution stage...... 682 /1000
# Execution stage...... 683 /1000
# Execution stage...... 684 /1000
# Execution stage...... 685 /1000
# Execution stage...... 686 /1000
# Execution stage...... 687 /1000
# Execution stage...... 688 /1000
# Execution stage...... 689 /1000
# Execution stage...... 690 /1000
# Execution stage...... 691 /1000
# Execution stage...... 692 /1000
# Execution stage...... 693 /1000
# Execution stage...... 694 /1000
# Execution stage...... 695 /1000
# Execution stage...... 696 /1000
# Execution stage...... 697 /1000
# Execution stage...... 698 /1000
# Execution stage...... 699 /1000
# Execution stage...... 700 /1000
# Execution stage...... 701 /1000
# Execution stage...... 702 /1000
# Execution stage...... 703 /1000
# Execution stage...... 704 /1000
# Execution stage...... 705 /1000
# Execution stage...... 706 /1000
# Execution stage...... 707 /1000
# Execution stage...... 708 /1000
# Execution stage...... 709 /1000
# Execution stage...... 710 /1000
# Execution stage...... 711 /1000
# Execution stage...... 712 /1000
# Execution stage...... 713 /1000
# Execution stage...... 714 /1000
# Execution stage...... 715 /1000
# Execution stage...... 716 /1000
# Execution stage...... 717 /1000
# Execution stage...... 718 /1000
# Execution stage...... 719 /1000
# Execution stage...... 720 /1000
# Execution stage...... 721 /1000
# Execution stage...... 722 /1000
# Execution stage...... 723 /1000
# Execution stage...... 724 /1000
# Execution stage...... 725 /1000
# Execution stage...... 726 /1000
# Execution stage...... 727 /1000
# Execution stage...... 728 /1000
# Execution stage...... 729 /1000
# Execution stage...... 730 /1000
# Execution stage...... 731 /1000
# Execution stage...... 732 /1000
# Execution stage...... 733 /1000
# Execution stage...... 734 /1000
# Execution stage...... 735 /1000
# Execution stage...... 736 /1000
# Execution stage...... 737 /1000
# Execution stage...... 738 /1000
# Execution stage...... 739 /1000
# Execution stage...... 740 /1000
# Execution stage...... 741 /1000
# Execution stage...... 742 /1000
# Execution stage...... 743 /1000
# Execution stage...... 744 /1000
# Execution stage...... 745 /1000
# Execution stage...... 746 /1000
# Execution stage...... 747 /1000
# Execution stage...... 748 /1000
# Execution stage...... 749 /1000
# Execution stage...... 750 /1000
# Execution stage...... 751 /1000
# Execution stage...... 752 /1000
# Execution stage...... 753 /1000
# Execution stage...... 754 /1000
# Execution stage...... 755 /1000
# Execution stage...... 756 /1000
# Execution stage...... 757 /1000
# Execution stage...... 758 /1000
# Execution stage...... 759 /1000
# Execution stage...... 760 /1000
# Execution stage...... 761 /1000
# Execution stage...... 762 /1000
# Execution stage...... 763 /1000
# Execution stage...... 764 /1000
# Execution stage...... 765 /1000
# Execution stage...... 766 /1000
# Execution stage...... 767 /1000
# Execution stage...... 768 /1000
# Execution stage...... 769 /1000
# Execution stage...... 770 /1000
# Execution stage...... 771 /1000
# Execution stage...... 772 /1000
# Execution stage...... 773 /1000
# Execution stage...... 774 /1000
# Execution stage...... 775 /1000
# Execution stage...... 776 /1000
# Execution stage...... 777 /1000
# Execution stage...... 778 /1000
# Execution stage...... 779 /1000
# Execution stage...... 780 /1000
# Execution stage...... 781 /1000
# Execution stage...... 782 /1000
# Execution stage...... 783 /1000
# Execution stage...... 784 /1000
# Execution stage...... 785 /1000
# Execution stage...... 786 /1000
# Execution stage...... 787 /1000
# Execution stage...... 788 /1000
# Execution stage...... 789 /1000
# Execution stage...... 790 /1000
# Execution stage...... 791 /1000
# Execution stage...... 792 /1000
# Execution stage...... 793 /1000
# Execution stage...... 794 /1000
# Execution stage...... 795 /1000
# Execution stage...... 796 /1000
# Execution stage...... 797 /1000
# Execution stage...... 798 /1000
# Execution stage...... 799 /1000
# Execution stage...... 800 /1000
# Execution stage...... 801 /1000
# Execution stage...... 802 /1000
# Execution stage...... 803 /1000
# Execution stage...... 804 /1000
# Execution stage...... 805 /1000
# Execution stage...... 806 /1000
# Execution stage...... 807 /1000
# Execution stage...... 808 /1000
# Execution stage...... 809 /1000
# Execution stage...... 810 /1000
# Execution stage...... 811 /1000
# Execution stage...... 812 /1000
# Execution stage...... 813 /1000
# Execution stage...... 814 /1000
# Execution stage...... 815 /1000
# Execution stage...... 816 /1000
# Execution stage...... 817 /1000
# Execution stage...... 818 /1000
# Execution stage...... 819 /1000
# Execution stage...... 820 /1000
# Execution stage...... 821 /1000
# Execution stage...... 822 /1000
# Execution stage...... 823 /1000
# Execution stage...... 824 /1000
# Execution stage...... 825 /1000
# Execution stage...... 826 /1000
# Execution stage...... 827 /1000
# Execution stage...... 828 /1000
# Execution stage...... 829 /1000
# Execution stage...... 830 /1000
# Execution stage...... 831 /1000
# Execution stage...... 832 /1000
# Execution stage...... 833 /1000
# Execution stage...... 834 /1000
# Execution stage...... 835 /1000
# Execution stage...... 836 /1000
# Execution stage...... 837 /1000
# Execution stage...... 838 /1000
# Execution stage...... 839 /1000
# Execution stage...... 840 /1000
# Execution stage...... 841 /1000
# Execution stage...... 842 /1000
# Execution stage...... 843 /1000
# Execution stage...... 844 /1000
# Execution stage...... 845 /1000
# Execution stage...... 846 /1000
# Execution stage...... 847 /1000
# Execution stage...... 848 /1000
# Execution stage...... 849 /1000
# Execution stage...... 850 /1000
# Execution stage...... 851 /1000
# Execution stage...... 852 /1000
# Execution stage...... 853 /1000
# Execution stage...... 854 /1000
# Execution stage...... 855 /1000
# Execution stage...... 856 /1000
# Execution stage...... 857 /1000
# Execution stage...... 858 /1000
# Execution stage...... 859 /1000
# Execution stage...... 860 /1000
# Execution stage...... 861 /1000
# Execution stage...... 862 /1000
# Execution stage...... 863 /1000
# Execution stage...... 864 /1000
# Execution stage...... 865 /1000
# Execution stage...... 866 /1000
# Execution stage...... 867 /1000
# Execution stage...... 868 /1000
# Execution stage...... 869 /1000
# Execution stage...... 870 /1000
# Execution stage...... 871 /1000
# Execution stage...... 872 /1000
# Execution stage...... 873 /1000
# Execution stage...... 874 /1000
# Execution stage...... 875 /1000
# Execution stage...... 876 /1000
# Execution stage...... 877 /1000
# Execution stage...... 878 /1000
# Execution stage...... 879 /1000
# Execution stage...... 880 /1000
# Execution stage...... 881 /1000
# Execution stage...... 882 /1000
# Execution stage...... 883 /1000
# Execution stage...... 884 /1000
# Execution stage...... 885 /1000
# Execution stage...... 886 /1000
# Execution stage...... 887 /1000
# Execution stage...... 888 /1000
# Execution stage...... 889 /1000
# Execution stage...... 890 /1000
# Execution stage...... 891 /1000
# Execution stage...... 892 /1000
# Execution stage...... 893 /1000
# Execution stage...... 894 /1000
# Execution stage...... 895 /1000
# Execution stage...... 896 /1000
# Execution stage...... 897 /1000
# Execution stage...... 898 /1000
# Execution stage...... 899 /1000
# Execution stage...... 900 /1000
# Execution stage...... 901 /1000
# Execution stage...... 902 /1000
# Execution stage...... 903 /1000
# Execution stage...... 904 /1000
# Execution stage...... 905 /1000
# Execution stage...... 906 /1000
# Execution stage...... 907 /1000
# Execution stage...... 908 /1000
# Execution stage...... 909 /1000
# Execution stage...... 910 /1000
# Execution stage...... 911 /1000
# Execution stage...... 912 /1000
# Execution stage...... 913 /1000
# Execution stage...... 914 /1000
# Execution stage...... 915 /1000
# Execution stage...... 916 /1000
# Execution stage...... 917 /1000
# Execution stage...... 918 /1000
# Execution stage...... 919 /1000
# Execution stage...... 920 /1000
# Execution stage...... 921 /1000
# Execution stage...... 922 /1000
# Execution stage...... 923 /1000
# Execution stage...... 924 /1000
# Execution stage...... 925 /1000
# Execution stage...... 926 /1000
# Execution stage...... 927 /1000
# Execution stage...... 928 /1000
# Execution stage...... 929 /1000
# Execution stage...... 930 /1000
# Execution stage...... 931 /1000
# Execution stage...... 932 /1000
# Execution stage...... 933 /1000
# Execution stage...... 934 /1000
# Execution stage...... 935 /1000
# Execution stage...... 936 /1000
# Execution stage...... 937 /1000
# Execution stage...... 938 /1000
# Execution stage...... 939 /1000
# Execution stage...... 940 /1000
# Execution stage...... 941 /1000
# Execution stage...... 942 /1000
# Execution stage...... 943 /1000
# Execution stage...... 944 /1000
# Execution stage...... 945 /1000
# Execution stage...... 946 /1000
# Execution stage...... 947 /1000
# Execution stage...... 948 /1000
# Execution stage...... 949 /1000
# Execution stage...... 950 /1000
# Execution stage...... 951 /1000
# Execution stage...... 952 /1000
# Execution stage...... 953 /1000
# Execution stage...... 954 /1000
# Execution stage...... 955 /1000
# Execution stage...... 956 /1000
# Execution stage...... 957 /1000
# Execution stage...... 958 /1000
# Execution stage...... 959 /1000
# Execution stage...... 960 /1000
# Execution stage...... 961 /1000
# Execution stage...... 962 /1000
# Execution stage...... 963 /1000
# Execution stage...... 964 /1000
# Execution stage...... 965 /1000
# Execution stage...... 966 /1000
# Execution stage...... 967 /1000
# Execution stage...... 968 /1000
# Execution stage...... 969 /1000
# Execution stage...... 970 /1000
# Execution stage...... 971 /1000
# Execution stage...... 972 /1000
# Execution stage...... 973 /1000
# Execution stage...... 974 /1000
# Execution stage...... 975 /1000
# Execution stage...... 976 /1000
# Execution stage...... 977 /1000
# Execution stage...... 978 /1000
# Execution stage...... 979 /1000
# Execution stage...... 980 /1000
# Execution stage...... 981 /1000
# Execution stage...... 982 /1000
# Execution stage...... 983 /1000
# Execution stage...... 984 /1000
# Execution stage...... 985 /1000
# Execution stage...... 986 /1000
# Execution stage...... 987 /1000
# Execution stage...... 988 /1000
# Execution stage...... 989 /1000
# Execution stage...... 990 /1000
# Execution stage...... 991 /1000
# Execution stage...... 992 /1000
# Execution stage...... 993 /1000
# Execution stage...... 994 /1000
# Execution stage...... 995 /1000
# Execution stage...... 996 /1000
# Execution stage...... 997 /1000
# Execution stage...... 998 /1000
# Execution stage...... 999 /1000

# %%
#plt.figure(figsize=(10,4))
l = []

a = np.sum(job_ads['mapreduce'])/1000

b = np.sum(job_ads['spark'])/1000
c = np.sum(job_ads['visualization'])/1000
d = np.sum(job_ads['Java'])/1000
e = np.sum(job_ads['python'])/1000
f = np.sum(job_ads['communication'])/1000
g = np.sum(job_ads['collaborate'])/1000
h = np.sum(job_ads['machine learning'])/1000
i = np.sum(job_ads['research'])/1000
j = np.sum(job_ads['analytics'])/1000
k = np.sum(job_ads['testing'])/1000
l = np.sum(job_ads['algorithms'])/1000
m = np.sum(job_ads['regression'])/1000
n = np.sum(job_ads['matlab'])/1000
o = np.sum(job_ads['excel'])/1000
p = np.sum(job_ads['hadoop'])/1000
q = np.sum(job_ads['mining'])/1000
r = np.sum(job_ads['dashboards'])/1000
s = np.sum(job_ads['statistics'])/1000
t = np.sum(job_ads['presentation'])/1000

print(b)
#skill_set.keys()

job_ads

skill_dict = {'mapreduce':sum(job_ads['mapreduce'] == 1), 'spark':sum(job_ads['spark'] == 1), 'visualization':sum(job_ads['visualization'] == 1), 'machine learning':sum(job_ads['machine learning'] == 1),
             'Statistics':sum(job_ads['statistics'] == 1), 'java':sum(job_ads['Java'] == 1),
             'communication':sum(job_ads['communication'] == 1), 'analytics':sum(job_ads['analytics'] == 1),
             'testing':sum(job_ads['testing'] == 1), 'algorithms':sum(job_ads['algorithms'] == 1),
             'matlab':sum(job_ads['matlab'] == 1), 'mining':sum(job_ads['mining'] == 1),
             'hadoop':sum(job_ads['hadoop'] == 1), 'python':sum(job_ads['python'] == 1), 'regression':sum(job_ads['regression'] == 1),
             'excel':sum(job_ads['excel'] == 1), 'presentation':sum(job_ads['presentation'] == 1), 
             'mining':sum(job_ads['mining'] == 1), 'research':sum(job_ads['research'] == 1),
             'collaborate':sum(job_ads['collaborate'] == 1)}
             
skill_dict
s = pd.Series(skill_dict)
s = pd.Series.sort_values(s)
s.plot.barh()
plt.xlabel("Frequency")
plt.ylabel("Skill")
plt.title("Frequency of Skills Required")

loc_s = job_ads['job location']

ny = loc_s.str.contains('NY').sum()
wa = loc_s.str.contains('WA').sum()
ca = loc_s.str.contains('CA').sum()
ma = loc_s.str.contains('MA').sum()
il = loc_s.str.contains('IL').sum()
dc = loc_s.str.contains('DC').sum()
tx = loc_s.str.contains('TX').sum()
nm = loc_s.str.contains('NM').sum()
ga = loc_s.str.contains('GA').sum()
pa = loc_s.str.contains('PA').sum()
mo = loc_s.str.contains('MO').sum()
va = loc_s.str.contains('VA').sum()

other = 1000 - ny - wa - ca - ma - il - dc - tx - nm - ga - pa - mo - va
loc_dict = {'NY':ny, 'WA':wa, 'CA':ca, 'MA':ma, 'IL':il, 'DC':dc, 'TX':tx,
            'GA':ga, 'PA':pa, 'VA':va, 'Other':other}

l = pd.Series(loc_dict)

print("State\tPostings")
l = pd.Series.sort_values(l)
l


plt.figure(figsize=(10,10))
l.plot.pie()
plt.ylabel("")
plt.title("Jobs Per State")
# Out:
# 0.295
# State	Postings
# Text(0.5, 1.0, 'Jobs Per State')
